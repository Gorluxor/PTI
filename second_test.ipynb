# %%
import piq

# %%
from piq import MultiScaleGMSDLoss

# %%
MultiScaleGMSDLoss?

# %%
import tntorch

# %%
import torch

# %%
loss = MultiScaleGMSDLoss()
x = torch.rand(3, 3, 256, 256, requires_grad=True).cuda()
y = torch.rand(3, 3, 256, 256).cuda()
output = loss(x, y)
output.backward()

# %%
output
# Out:
# tensor(0.1949, device='cuda:0', grad_fn=<MeanBackward1>)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar?

# %%
fig, ax = plt.subplots()

# %%
fig.bar?
# Out:
# Object `fig.bar` not found.

# %%
import torch as trch
import torchvision.datasets as dts 
import torchvision.transforms as trnsfrms
import torch.nn as nn
import matplotlib.pyplot as plot

trnsform = trnsfrms.Compose([trnsfrms.ToTensor(), trnsfrms.Normalize((0.7,), (0.7,)),])

mnisttrainset = dts.MNIST(root='./data', train=True, download=True, transform=trnsform)
trainldr = trch.utils.data.DataLoader(mnisttrainset, batch_size=10, shuffle=True)

mnist_testset = dts.MNIST(root='./data', train=False, download=True, transform=trnsform)
testldr = trch.utils.data.DataLoader(mnist_testset, batch_size=10, shuffle=True)
trnsform = trnsfrms.Compose([trnsfrms.ToTensor(), trnsfrms.Normalize((0.7,), (0.7,)),])
class classicationmodel(nn.Module):
    def __init__(self):
        super( classicationmodel,self).__init__()
        self.linear1 = nn.Linear(28*28, 100) 
        self.linear2 = nn.Linear(100, 50) 
        self.final = nn.Linear(50, 10)
        self.relu = nn.ReLU()

    def forward(self, image):
        a = image.view(-1, 28*28)
        a = self.relu(self.linear1(a))
        a = self.relu(self.linear2(a))
        a = self.final(a)
        return a

cmodel = classicationmodel()
print(cmodel)


b_w1 = cmodel.linear1.weight.clone().detach()
b_w2 = cmodel.linear2.weight.clone().detach()
b_b1 = cmodel.linear1.bias.clone().detach()
b_b2 = cmodel.linear2.bias.clone().detach()

import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(cmodel.parameters(), lr=0.001, momentum=0.9)

for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainldr, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = cmodel(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
            running_loss = 0.0

print('Finished Training')
a_w1 = cmodel.linear1.weight.clone().detach()
a_w2 = cmodel.linear2.weight.clone().detach()
a_b1 = cmodel.linear1.bias.clone().detach()
a_b2 = cmodel.linear2.bias.clone().detach()

print(sum(sum(abs(b_w1-a_w1))))
print(sum(sum(abs(b_w2-a_w2))))
print(sum((abs(b_b1-a_b1))))
print(sum((abs(b_b2-a_b2))))
# Out:
# classicationmodel(
#   (linear1): Linear(in_features=784, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=50, bias=True)
#   (final): Linear(in_features=50, out_features=10, bias=True)
#   (relu): ReLU()
# )
# [1,  2000] loss: 0.933
# [1,  4000] loss: 0.395
# [1,  6000] loss: 0.335
# [2,  2000] loss: 0.285
# [2,  4000] loss: 0.256
# [2,  6000] loss: 0.226
# Finished Training
# tensor(917.6404)
# tensor(144.1938)
# tensor(0.2870)
# tensor(0.5789)

# %% [markdown]
# Disable middle part to see if gradient flows

# %%
import torch as trch
import torchvision.datasets as dts 
import torchvision.transforms as trnsfrms
import torch.nn as nn
import matplotlib.pyplot as plot

trnsform = trnsfrms.Compose([trnsfrms.ToTensor(), trnsfrms.Normalize((0.7,), (0.7,)),])

mnisttrainset = dts.MNIST(root='./data', train=True, download=True, transform=trnsform)
trainldr = trch.utils.data.DataLoader(mnisttrainset, batch_size=10, shuffle=True)

mnist_testset = dts.MNIST(root='./data', train=False, download=True, transform=trnsform)
testldr = trch.utils.data.DataLoader(mnist_testset, batch_size=10, shuffle=True)
trnsform = trnsfrms.Compose([trnsfrms.ToTensor(), trnsfrms.Normalize((0.7,), (0.7,)),])
class classicationmodel(nn.Module):
    def __init__(self):
        super( classicationmodel,self).__init__()
        self.linear1 = nn.Linear(28*28, 100) 
        self.linear2 = nn.Linear(100, 50) 
        self.final = nn.Linear(50, 10)
        self.relu = nn.ReLU()

    def forward(self, image):
        a = image.view(-1, 28*28)
        a = self.relu(self.linear1(a))
        a = self.relu(self.linear2(a))
        a = self.final(a)
        return a

cmodel = classicationmodel()
print(cmodel)


b_w1 = cmodel.linear1.weight.clone().detach()
b_w2 = cmodel.linear2.weight.clone().detach()
b_b1 = cmodel.linear1.bias.clone().detach()
b_b2 = cmodel.linear2.bias.clone().detach()

import torch.optim as optim

cmodel.linear2.requires_grad_(False)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(cmodel.parameters(), lr=0.001, momentum=0.9)

for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainldr, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = cmodel(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
            running_loss = 0.0

print('Finished Training')
a_w1 = cmodel.linear1.weight.clone().detach()
a_w2 = cmodel.linear2.weight.clone().detach()
a_b1 = cmodel.linear1.bias.clone().detach()
a_b2 = cmodel.linear2.bias.clone().detach()

print(sum(sum(abs(b_w1-a_w1))))
print(sum(sum(abs(b_w2-a_w2))))
print(sum((abs(b_b1-a_b1))))
print(sum((abs(b_b2-a_b2))))
# Out:
# classicationmodel(
#   (linear1): Linear(in_features=784, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=50, bias=True)
#   (final): Linear(in_features=50, out_features=10, bias=True)
#   (relu): ReLU()
# )
# [1,  2000] loss: 1.104
# [1,  4000] loss: 0.438
# [1,  6000] loss: 0.367
# [2,  2000] loss: 0.329
# [2,  4000] loss: 0.312
# [2,  6000] loss: 0.301
# Finished Training
# tensor(1070.6332)
# tensor(0.)
# tensor(0.5121)
# tensor(0.)

# %%
def ping(n):
    print(f'ping {n}')
    pong(n+1)
def pong(n):
    print(f"pong {n}")
    ping(n+1)
ping(0)
# Out:
# ping 0
# pong 1
# ping 2
# pong 3
# ping 4
# pong 5
# ping 6
# pong 7
# ping 8
# pong 9
# ping 10
# pong 11
# ping 12
# pong 13
# ping 14
# pong 15
# ping 16
# pong 17
# ping 18
# pong 19
# ping 20
# pong 21
# ping 22
# pong 23
# ping 24
# pong 25
# ping 26
# pong 27
# ping 28
# pong 29
# ping 30
# pong 31
# ping 32
# pong 33
# ping 34
# pong 35
# ping 36
# pong 37
# ping 38
# pong 39
# ping 40
# pong 41
# ping 42
# pong 43
# ping 44
# pong 45
# ping 46
# pong 47
# ping 48
# pong 49
# ping 50
# pong 51
# ping 52
# pong 53
# ping 54
# pong 55
# pong 2783
# ping 2784
# pong 2785
# ping 2786
# pong 2787
# ping 2788
# pong 2789
# ping 2790
# pong 2791
# ping 2792
# pong 2793
# ping 2794
# pong 2795
# ping 2796
# pong 2797
# ping 2798
# pong 2799
# ping 2800
# pong 2801
# ping 2802
# pong 2803
# ping 2804
# pong 2805
# ping 2806
# pong 2807
# ping 2808
# pong 2809
# ping 2810
# pong 2811
# ping 2812
# pong 2813
# ping 2814
# pong 2815
# ping 2816
# pong 2817
# ping 2818
# pong 2819
# ping 2820
# pong 2821
# ping 2822
# pong 2823
# ping 2824
# pong 2825
# ping 2826
# pong 2827
# ping 2828
# pong 2829
# ping 2830
# pong 2831
# ping 2832
# pong 2833
# ping 2834
# pong 2835
# ping 2836
# pong 2837
# ping 2838
# pong 2839
# ping 2840
# pong 2841
# ping 2842
# pong 2843
# ping 2844
# pong 2845
# ping 2846
# pong 2847
# ping 2848
# pong 2849
# ping 2850
# pong 2851
# ping 2852
# pong 2853
# ping 2854
# pong 2855
# ping 2856
# pong 2857
# ping 2858
# pong 2859
# ping 2860
# pong 2861
# ping 2862
# pong 2863
# ping 2864
# pong 2865
# ping 2866
# pong 2867
# ping 2868
# pong 2869
# ping 2870
# pong 2871
# ping 2872
# pong 2873
# ping 2874
# pong 2875
# ping 2876
# pong 2877
# ping 2878
# pong 2879
# ping 2880
# pong 2881
# ping 2882
# pong 2883
# ping 2884
# pong 2885
# ping 2886
# pong 2887
# ping 2888
# pong 2889
# ping 2890
# pong 2891
# ping 2892
# pong 2893
# ping 2894
# pong 2895
# ping 2896
# pong 2897
# ping 2898
# pong 2899
# ping 2900
# pong 2901
# ping 2902
# pong 2903
# ping 2904
# pong 2905
# ping 2906
# pong 2907
# ping 2908
# pong 2909
# ping 2910
# pong 2911
# ping 2912
# pong 2913
# ping 2914
# pong 2915
# ping 2916
# pong 2917
# ping 2918
# pong 2919
# ping 2920
# pong 2921
# ping 2922
# pong 2923
# ping 2924
# pong 2925
# ping 2926
# pong 2927
# ping 2928
# pong 2929
# ping 2930
# pong 2931
# ping 2932
# pong 2933
# ping 2934
# pong 2935
# ping 2936
# pong 2937
# ping 2938
# pong 2939
# ping 2940
# pong 2941
# ping 2942
# pong 2943
# ping 2944
# pong 2945
# ping 2946
# pong 2947
# ping 2948
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-36-9c52a9597996> in <module>
#       5     print(f"pong {n}")
#       6     ping(n+1)
# ----> 7 ping(0)
#
# <ipython-input-36-9c52a9597996> in ping(n)
#       1 def ping(n):
#       2     print(f'ping {n}')
# ----> 3     pong(n+1)
#       4 def pong(n):
#       5     print(f"pong {n}")
#
# <ipython-input-36-9c52a9597996> in pong(n)
#       4 def pong(n):
#       5     print(f"pong {n}")
# ----> 6     ping(n+1)
#       7 ping(0)
#
# ... last 2 frames repeated, from the frame below ...
#
# <ipython-input-36-9c52a9597996> in ping(n)
#       1 def ping(n):
#       2     print(f'ping {n}')
# ----> 3     pong(n+1)
#       4 def pong(n):
#       5     print(f"pong {n}")
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
